# %%
# For loops

# %%
numbers = [2,3,4,5]
sum = 0

# %%
for i in numbers:
    sum = sum + i

# %%
print("The sum of numbers vector is:",  sum)
# Out:
# The sum of numbers vector is: 14

# %%
# Print text:
text = "Running"
for j in text:
    print(j)
# Out:
# R
# u
# n
# n
# i
# n
# g

# %%
# while loop
counter = 1
while counter < 5:
    print(counter)
    counter = counter + 1
# Out:
# 1
# 2
# 3
# 4
